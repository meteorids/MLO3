# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import numpy as np
import random
import math
import h5py
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# disable FutureWarning
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 

train_data_path='./Training_Data/'
output_path='./net/'

nnstr='Ozone' #NN name string
hiddenlayers=(100,90,75) #set MLNN hidden layers (hidden layers will be reset for aaNN based on number of bands)

#radoption=2 #TOA rad data type, options: 1=Lt, 2=Lrc 
addnoise=1 #Flag for adding Gaussian noise NOTE: do not add noise for forward training
noiselevel=1 #Gaussian noise level, e.g. 1=1%

#sensor band infos
band=[302,312,320,340,380]
trainband=np.arange(5)
nrrs=5
aodidx=np.arange(5)

#number of sample in the scatter plot, if total number of data points is less than this, half of the data will be used for plotting
nplotsample=5000 
	
nband=len(band)
ntrainband=len(trainband)
naod=len(aodidx) 
      
#read in training data
print('Loading training dataset...')
for i in np.arange(5):
    if i==0:       
       par=np.loadtxt(train_data_path +'NILU-training'+str(i+1)+'.txt')
    else:
       par=np.append(par,np.loadtxt(train_data_path +'NILU-training'+str(i+1)+'.txt'),0)

print('Training dataset loaded.')



#remove negative values
idx=np.where(np.sum(par<0,axis=1)==0)[0]
par=par[idx,:]

#total number of training cases
ncase=len(par)
rad=np.zeros((ncase,2))

rad[:,0] = par[:,3]
rad[:,1] = par[:,4]

#generate the gaussian noise for each band
if addnoise==1:
    fname_prefix=nnstr+'WiGN_p'+str(noiselevel)
    noise=np.random.normal(1,noiselevel/100,(ncase,1))    # only use 2 ratio
    rad=np.multiply(rad,noise) 
else:
    fname_prefix=nnstr+'WoGN' 
     
# NN training: Ozone & Cloud Optical Depth   
#trainingoption = itrain + 1

nnlayer = hiddenlayers
            
nlayer=len(nnlayer) # number of hidden layers
    
#create layer string for file name
layerstr=''
for i in np.arange(nlayer):
    if i<nlayer-1:
       layerstr=layerstr+str(nnlayer[i])+'X'
    else:
       layerstr=layerstr+str(nnlayer[i])

trainx=np.zeros((ncase,3))
trainy=np.zeros((ncase,2))

trainx[:,0]=np.cos(np.deg2rad(par[:,0])) # geometry: cos[Solar Zenith Angle]
trainx[:,1]=np.log10(rad[:,0]) # Irradiance 380
trainx[:,2]=np.log10(rad[:,1]) # Ratio

trainy[:,0]=np.log10(par[:,1]) # Ozone
trainy[:,1]=np.log10(par[:,2]) # Cloud. Vol. Frac.

net_name='net_'+fname_prefix+'_ozone'+str(nrrs)+'_'+layerstr+'.h5'	  
for i in np.arange(nrrs):
    if i==0:
       labelparam=['Rrs'+str(band[i])+'nm']
    else:
       labelparam=np.append(labelparam,['Rrs'+str(band[i])+'nm'],0)			  

ninput=len(trainx[0])
train_in=np.zeros((ninput,2))
for i in range(ninput):
    train_in[i,0]=trainx[:,i].min()
    train_in[i,1]=trainx[:,i].max()
noutput=len(trainy[0])	
train_out=np.zeros((noutput,2))
for i in range(noutput):
    train_out[i,0]=trainy[:,i].min()
    train_out[i,1]=trainy[:,i].max()
#normalize the trainx and trainy to [-1,1]	
for i in range(ninput):
    trainx[:,i]=2*(trainx[:,i]-train_in[i,0])/(train_in[i,1]-train_in[i,0])-1
for i in range(noutput):
    trainy[:,i]=2*(trainy[:,i]-train_out[i,0])/(train_out[i,1]-train_out[i,0])-1

    
#set k-fold cross validation
k = 5
kf = KFold(n_splits=k, random_state=None)

#Build MLNN
mlnn=MLPRegressor(hidden_layer_sizes=nnlayer,
     activation='tanh',
	  solver='adam',
    	  batch_size='auto',
    	  learning_rate='adaptive',
    	  learning_rate_init=0.001,
    	  max_iter=1000,
    	  random_state=5,
    	  tol=1.0e-8,
    	  verbose=True,
    	  early_stopping=True,  
    	  validation_fraction=0.1)
#traing MLNN
mlnn=mlnn.fit(trainx,trainy)
    
#save trained NN to HDF5
nn_structure=np.zeros([nlayer+2])
nn_structure[0]=ninput
for i in range(nlayer):
    nn_structure[i+1]=nnlayer[i]
nn_structure[nlayer+1]=noutput
    
hf = h5py.File('./net/'+net_name,'w')
hf.create_dataset('Layers',dtype='int8',data = nn_structure)
hf.create_dataset('Norm_in',dtype='float64',data = train_in)
hf.create_dataset('Norm_out',dtype='float64',data = train_out)
gw = hf.create_group('Weights')
for i in range(nlayer+1):    
    gw.create_dataset('Layer'+str(i+1),dtype='float64',data=np.transpose(mlnn.coefs_[i]))
gb = hf.create_group('Bias')
for i in range(nlayer+1):
    gb.create_dataset('Layer'+str(i+1),dtype='float64',data=mlnn.intercepts_[i].reshape(int(nn_structure[i+1]),1))
hf.close()   

#k-fold cross validation
result = cross_val_score(mlnn , trainx, trainy, cv = kf)
print('Cross validation score:')
print(result)

#make prediction using trained MLNN
nnoutput=mlnn.predict(trainx)
#converting data
for i in range(noutput):
    nnoutput[:,i]=(nnoutput[:,i]+1)/2*(train_out[i,1]-train_out[i,0])+train_out[i,0]
    trainy[:,i]=(trainy[:,i]+1)/2*(train_out[i,1]-train_out[i,0])+train_out[i,0]
	
nnoutput=10 ** nnoutput
trainy=10 ** trainy
    
#compute average percentage error
diff=(nnoutput-trainy)/trainy*100
ape=np.mean(np.absolute(diff), axis=0)
bias=np.mean(diff, axis=0)
    
lim=np.amax(trainy,axis=0)*1.2 #set limit
r2=np.zeros(noutput)
if ncase>nplotsample:
    idx=random.sample(list(range(ncase)),nplotsample)
else:
    idx=random.sample(list(range(ncase)),int(ncase/2))
if noutput<5:
    plt.figure(figsize=(18,5),dpi=150)
else:
    plt.figure(figsize=(18,9),dpi=150)
for i in np.arange(noutput):
    r2[i]=r2_score(trainy[:,i],nnoutput[:,i])
    print(r2[i])
    plt.subplot(2,4,i+1)           
    plt.scatter(trainy[idx,i],nnoutput[idx,i],s=2,c='red')
    plt.xlim(0, lim[i])
    plt.ylim(0, lim[i])
    plt.xlabel('Model '+labelparam[i]) #original line:   plt.xlabel('Model '+labelparam[i])
    plt.ylabel('MLNN '+labelparam[i])  #original line: plt.ylabel('MLNN '+labelparam[i])
    plt.plot([0,lim[i]],[0,lim[i]],'k')
    plt.text(lim[i]*0.05,lim[i]*0.94,('R$^2$ = %0.3f' % (r2[i])))
    plt.text(lim[i]*0.05,lim[i]*0.88,('APE = %0.2f' % (ape[i])+'%'))
    plt.text(lim[i]*0.05,lim[i]*0.82,('Bias = %0.2f' % (bias[i])+'%'))
plt.tight_layout()
plt.savefig(output_path+net_name+'_Training.pdf', dpi=300)
# Out:
# Loading training dataset...
# Training dataset loaded.
# Iteration 1, loss = 0.03756694
# Validation score: 0.956401
# Iteration 2, loss = 0.00254613
# Validation score: 0.980231
# Iteration 3, loss = 0.00148362
# Validation score: 0.985273
# Iteration 4, loss = 0.00123127
# Validation score: 0.986597
# Iteration 5, loss = 0.00112559
# Validation score: 0.988040
# Iteration 6, loss = 0.00101925
# Validation score: 0.989142
# Iteration 7, loss = 0.00089580
# Validation score: 0.990079
# Iteration 8, loss = 0.00078943
# Validation score: 0.991862
# Iteration 9, loss = 0.00067018
# Validation score: 0.992718
# Iteration 10, loss = 0.00056864
# Validation score: 0.993993
# Iteration 11, loss = 0.00050746
# Validation score: 0.994458
# Iteration 12, loss = 0.00047388
# Validation score: 0.994795
# Iteration 13, loss = 0.00044956
# Validation score: 0.995047
# Iteration 14, loss = 0.00042777
# Validation score: 0.995400
# Iteration 15, loss = 0.00039925
# Validation score: 0.995347
# Iteration 16, loss = 0.00039496
# Validation score: 0.995227
# Iteration 17, loss = 0.00036928
# Validation score: 0.995659
# Iteration 18, loss = 0.00037536
# Validation score: 0.995607
# Iteration 19, loss = 0.00035916
# Validation score: 0.995943
# Iteration 20, loss = 0.00033403
# Validation score: 0.996068
# Iteration 21, loss = 0.00033099
# Validation score: 0.996583
# Iteration 22, loss = 0.00032228
# Validation score: 0.996562
# Iteration 23, loss = 0.00029138
# Validation score: 0.996881
# Iteration 24, loss = 0.00028255
# Validation score: 0.996318
# Iteration 25, loss = 0.00027796
# Validation score: 0.997035
# Iteration 26, loss = 0.00026843
# Validation score: 0.996380
# Iteration 27, loss = 0.00030179
# Validation score: 0.996737
# Iteration 28, loss = 0.00026153
# Validation score: 0.997201
# Iteration 29, loss = 0.00025333
# Validation score: 0.997168
# Iteration 30, loss = 0.00024450
# Validation score: 0.997415
# Iteration 31, loss = 0.00025216
# Validation score: 0.997155
# Iteration 32, loss = 0.00024247
# Validation score: 0.997128
# Iteration 33, loss = 0.00023358
# Validation score: 0.997556
# Iteration 34, loss = 0.00026192
# Validation score: 0.997475
# Iteration 35, loss = 0.00024015
# Validation score: 0.997144
# Iteration 36, loss = 0.00025971
# Validation score: 0.997684
# Iteration 37, loss = 0.00023688
# Validation score: 0.997577
# Iteration 38, loss = 0.00022778
# Validation score: 0.997237
# Iteration 39, loss = 0.00022632
# Validation score: 0.997505
# Iteration 40, loss = 0.00021754
# Validation score: 0.997777
# Iteration 41, loss = 0.00020866
# Validation score: 0.997501
# Iteration 42, loss = 0.00023218
# Validation score: 0.997945
# Iteration 43, loss = 0.00021974
# Validation score: 0.997431
# Iteration 44, loss = 0.00022436
# Validation score: 0.997442
# Iteration 45, loss = 0.00021729
# Validation score: 0.997826
# Iteration 46, loss = 0.00022586
# Validation score: 0.997955
# Iteration 47, loss = 0.00020052
# Validation score: 0.997604
# Iteration 48, loss = 0.00021521
# Validation score: 0.997929
# Iteration 49, loss = 0.00022065
# Validation score: 0.998071
# Iteration 50, loss = 0.00024369
# Validation score: 0.997479
# Iteration 51, loss = 0.00020451
# Validation score: 0.996884
# Iteration 52, loss = 0.00021338
# Validation score: 0.997988
# Iteration 53, loss = 0.00024675
# Validation score: 0.997791
# Iteration 54, loss = 0.00020906
# Validation score: 0.997963
# Iteration 55, loss = 0.00020846
# Validation score: 0.997302
# Iteration 56, loss = 0.00020347
# Validation score: 0.998195
# Iteration 57, loss = 0.00019507
# Validation score: 0.998162
# Iteration 58, loss = 0.00024836
# Validation score: 0.998055
# Iteration 59, loss = 0.00018458
# Validation score: 0.997286
# Iteration 60, loss = 0.00019438
# Validation score: 0.997752
# Iteration 61, loss = 0.00019438
# Validation score: 0.998126
# Iteration 62, loss = 0.00019706
# Validation score: 0.997995
# Iteration 63, loss = 0.00018917
# Validation score: 0.997643
# Iteration 64, loss = 0.00018829
# Validation score: 0.997901
# Iteration 65, loss = 0.00018999
# Validation score: 0.997906
# Iteration 66, loss = 0.00018189
# Validation score: 0.997264
# Iteration 67, loss = 0.00022074
# Validation score: 0.998139
# Validation score did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.04700482
# Validation score: 0.947322
# Iteration 2, loss = 0.00343755
# Validation score: 0.976293
# Iteration 3, loss = 0.00177663
# Validation score: 0.983760
# Iteration 4, loss = 0.00140570
# Validation score: 0.986199
# Iteration 5, loss = 0.00124731
# Validation score: 0.987265
# Iteration 6, loss = 0.00118345
# Validation score: 0.987962
# Iteration 7, loss = 0.00108899
# Validation score: 0.989249
# Iteration 8, loss = 0.00101158
# Validation score: 0.990005
# Iteration 9, loss = 0.00089993
# Validation score: 0.990937
# Iteration 10, loss = 0.00079067
# Validation score: 0.992212
# Iteration 11, loss = 0.00068664
# Validation score: 0.993561
# Iteration 12, loss = 0.00061855
# Validation score: 0.994170
# Iteration 13, loss = 0.00057015
# Validation score: 0.994515
# Iteration 14, loss = 0.00052380
# Validation score: 0.994929
# Iteration 15, loss = 0.00050026
# Validation score: 0.995075
# Iteration 16, loss = 0.00046747
# Validation score: 0.995350
# Iteration 17, loss = 0.00044540
# Validation score: 0.995704
# Iteration 18, loss = 0.00044081
# Validation score: 0.995747
# Iteration 19, loss = 0.00042016
# Validation score: 0.995985
# Iteration 20, loss = 0.00041868
# Validation score: 0.996143
# Iteration 21, loss = 0.00038418
# Validation score: 0.996258
# Iteration 22, loss = 0.00038373
# Validation score: 0.996293
# Iteration 23, loss = 0.00037898
# Validation score: 0.996286
# Iteration 24, loss = 0.00035267
# Validation score: 0.996638
# Iteration 25, loss = 0.00033720
# Validation score: 0.996463
# Iteration 26, loss = 0.00032854
# Validation score: 0.997021
# Iteration 27, loss = 0.00031215
# Validation score: 0.997095
# Iteration 28, loss = 0.00030973
# Validation score: 0.996942
# Iteration 29, loss = 0.00030175
# Validation score: 0.997320
# Iteration 30, loss = 0.00028087
# Validation score: 0.997327
# Iteration 31, loss = 0.00028331
# Validation score: 0.997417
# Iteration 32, loss = 0.00028219
# Validation score: 0.996893
# Iteration 33, loss = 0.00029393
# Validation score: 0.997526
# Iteration 34, loss = 0.00028188
# Validation score: 0.997326
# Iteration 35, loss = 0.00027269
# Validation score: 0.997461
# Iteration 36, loss = 0.00025942
# Validation score: 0.997434
# Iteration 37, loss = 0.00028036
# Validation score: 0.997600
# Iteration 38, loss = 0.00026732
# Validation score: 0.997520
# Iteration 39, loss = 0.00025319
# Validation score: 0.997677
# Iteration 40, loss = 0.00026432
# Validation score: 0.996733
# Iteration 41, loss = 0.00026325
# Validation score: 0.997336
# Iteration 42, loss = 0.00026257
# Validation score: 0.997764
# Iteration 43, loss = 0.00025630
# Validation score: 0.997909
# Iteration 44, loss = 0.00024553
# Validation score: 0.997502
# Iteration 45, loss = 0.00024333
# Validation score: 0.997849
# Iteration 46, loss = 0.00024429
# Validation score: 0.997438
# Iteration 47, loss = 0.00023566
# Validation score: 0.997088
# Iteration 48, loss = 0.00025305
# Validation score: 0.997946
# Iteration 49, loss = 0.00022363
# Validation score: 0.997306
# Iteration 50, loss = 0.00025802
# Validation score: 0.998072
# Iteration 51, loss = 0.00024232
# Validation score: 0.997902
# Iteration 52, loss = 0.00024824
# Validation score: 0.997863
# Iteration 53, loss = 0.00024008
# Validation score: 0.997083
# Iteration 54, loss = 0.00022786
# Validation score: 0.998037
# Iteration 55, loss = 0.00024338
# Validation score: 0.997128
# Iteration 56, loss = 0.00023884
# Validation score: 0.997977
# Iteration 57, loss = 0.00026014
# Validation score: 0.998171
# Iteration 58, loss = 0.00021247
# Validation score: 0.998135
# Iteration 59, loss = 0.00021946
# Validation score: 0.997463
# Iteration 60, loss = 0.00022939
# Validation score: 0.997632
# Iteration 61, loss = 0.00023202
# Validation score: 0.998252
# Iteration 62, loss = 0.00020293
# Validation score: 0.998296
# Iteration 63, loss = 0.00021308
# Validation score: 0.998105
# Iteration 64, loss = 0.00021752
# Validation score: 0.997480
# Iteration 65, loss = 0.00022547
# Validation score: 0.998327
# Iteration 66, loss = 0.00020665
# Validation score: 0.998343
# Iteration 67, loss = 0.00023209
# Validation score: 0.998318
# Iteration 68, loss = 0.00020821
# Validation score: 0.997539
# Iteration 69, loss = 0.00021116
# Validation score: 0.998350
# Iteration 70, loss = 0.00020386
# Validation score: 0.996696
# Iteration 71, loss = 0.00021299
# Validation score: 0.997087
# Iteration 72, loss = 0.00023452
# Validation score: 0.997957
# Iteration 73, loss = 0.00020424
# Validation score: 0.998155
# Iteration 74, loss = 0.00020503
# Validation score: 0.998128
# Iteration 75, loss = 0.00021270
# Validation score: 0.998159
# Iteration 76, loss = 0.00020463
# Validation score: 0.997992
# Iteration 77, loss = 0.00019765
# Validation score: 0.998023
# Iteration 78, loss = 0.00021093
# Validation score: 0.998137
# Iteration 79, loss = 0.00022425
# Validation score: 0.998247
# Iteration 80, loss = 0.00020650
# Validation score: 0.997985
# Validation score did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.04668538
# Validation score: 0.947502
# Iteration 2, loss = 0.00329370
# Validation score: 0.976925
# Iteration 3, loss = 0.00171325
# Validation score: 0.983926
# Iteration 4, loss = 0.00134565
# Validation score: 0.987008
# Iteration 5, loss = 0.00118205
# Validation score: 0.988050
# Iteration 6, loss = 0.00111414
# Validation score: 0.988611
# Iteration 7, loss = 0.00104091
# Validation score: 0.989904
# Iteration 8, loss = 0.00096183
# Validation score: 0.990869
# Iteration 9, loss = 0.00085994
# Validation score: 0.991867
# Iteration 10, loss = 0.00077295
# Validation score: 0.993221
# Iteration 11, loss = 0.00066116
# Validation score: 0.994199
# Iteration 12, loss = 0.00058304
# Validation score: 0.994832
# Iteration 13, loss = 0.00053265
# Validation score: 0.995196
# Iteration 14, loss = 0.00049731
# Validation score: 0.995577
# Iteration 15, loss = 0.00047744
# Validation score: 0.996034
# Iteration 16, loss = 0.00044367
# Validation score: 0.996249
# Iteration 17, loss = 0.00042168
# Validation score: 0.996346
# Iteration 18, loss = 0.00040374
# Validation score: 0.996681
# Iteration 19, loss = 0.00038905
# Validation score: 0.996736
# Iteration 20, loss = 0.00038798
# Validation score: 0.996925
# Iteration 21, loss = 0.00036531
# Validation score: 0.997103
# Iteration 22, loss = 0.00035662
# Validation score: 0.997233
# Iteration 23, loss = 0.00035715
# Validation score: 0.997101
# Iteration 24, loss = 0.00033775
# Validation score: 0.997393
# Iteration 25, loss = 0.00031879
# Validation score: 0.997499
# Iteration 26, loss = 0.00031802
# Validation score: 0.997728
# Iteration 27, loss = 0.00031000
# Validation score: 0.997699
# Iteration 28, loss = 0.00029515
# Validation score: 0.997711
# Iteration 29, loss = 0.00029014
# Validation score: 0.998115
# Iteration 30, loss = 0.00028068
# Validation score: 0.997869
# Iteration 31, loss = 0.00027404
# Validation score: 0.998141
# Iteration 32, loss = 0.00026219
# Validation score: 0.998106
# Iteration 33, loss = 0.00027716
# Validation score: 0.998193
# Iteration 34, loss = 0.00027304
# Validation score: 0.998042
# Iteration 35, loss = 0.00026561
# Validation score: 0.998255
# Iteration 36, loss = 0.00025771
# Validation score: 0.997943
# Iteration 37, loss = 0.00025973
# Validation score: 0.998273
# Iteration 38, loss = 0.00027385
# Validation score: 0.997791
# Iteration 39, loss = 0.00025982
# Validation score: 0.998409
# Iteration 40, loss = 0.00024164
# Validation score: 0.998491
# Iteration 41, loss = 0.00024207
# Validation score: 0.998370
# Iteration 42, loss = 0.00024262
# Validation score: 0.998541
# Iteration 43, loss = 0.00025076
# Validation score: 0.998416
# Iteration 44, loss = 0.00023352
# Validation score: 0.998611
# Iteration 45, loss = 0.00022448
# Validation score: 0.998726
# Iteration 46, loss = 0.00023816
# Validation score: 0.998414
# Iteration 47, loss = 0.00022370
# Validation score: 0.998158
# Iteration 48, loss = 0.00024877
# Validation score: 0.998749
# Iteration 49, loss = 0.00022794
# Validation score: 0.998557
# Iteration 50, loss = 0.00024149
# Validation score: 0.998559
# Iteration 51, loss = 0.00024493
# Validation score: 0.998637
# Iteration 52, loss = 0.00022307
# Validation score: 0.998655
# Iteration 53, loss = 0.00022726
# Validation score: 0.998270
# Iteration 54, loss = 0.00024873
# Validation score: 0.998686
# Iteration 55, loss = 0.00022672
# Validation score: 0.998334
# Iteration 56, loss = 0.00022761
# Validation score: 0.998054
# Iteration 57, loss = 0.00024138
# Validation score: 0.998720
# Iteration 58, loss = 0.00021340
# Validation score: 0.998783
# Iteration 59, loss = 0.00020557
# Validation score: 0.998067
# Iteration 60, loss = 0.00023737
# Validation score: 0.997467
# Iteration 61, loss = 0.00022098
# Validation score: 0.998862
# Iteration 62, loss = 0.00021114
# Validation score: 0.998748
# Iteration 63, loss = 0.00020343
# Validation score: 0.998842
# Iteration 64, loss = 0.00021060
# Validation score: 0.998454
# Iteration 65, loss = 0.00021192
# Validation score: 0.998873
# Iteration 66, loss = 0.00021391
# Validation score: 0.998962
# Iteration 67, loss = 0.00021386
# Validation score: 0.998687
# Iteration 68, loss = 0.00021179
# Validation score: 0.997198
# Iteration 69, loss = 0.00022111
# Validation score: 0.998584
# Iteration 70, loss = 0.00021601
# Validation score: 0.998006
# Iteration 71, loss = 0.00019911
# Validation score: 0.998657
# Iteration 72, loss = 0.00019470
# Validation score: 0.998537
# Iteration 73, loss = 0.00021616
# Validation score: 0.998457
# Iteration 74, loss = 0.00019522
# Validation score: 0.998542
# Iteration 75, loss = 0.00021792
# Validation score: 0.998849
# Iteration 76, loss = 0.00018620
# Validation score: 0.997956
# Iteration 77, loss = 0.00020997
# Validation score: 0.998209
# Validation score did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.04717175
# Validation score: 0.944652
# Iteration 2, loss = 0.00336746
# Validation score: 0.973247
# Iteration 3, loss = 0.00176710
# Validation score: 0.981167
# Iteration 4, loss = 0.00138719
# Validation score: 0.984021
# Iteration 5, loss = 0.00123040
# Validation score: 0.985543
# Iteration 6, loss = 0.00115366
# Validation score: 0.985691
# Iteration 7, loss = 0.00108613
# Validation score: 0.987261
# Iteration 8, loss = 0.00100834
# Validation score: 0.988447
# Iteration 9, loss = 0.00089919
# Validation score: 0.989862
# Iteration 10, loss = 0.00080063
# Validation score: 0.990853
# Iteration 11, loss = 0.00069539
# Validation score: 0.992268
# Iteration 12, loss = 0.00062258
# Validation score: 0.993148
# Iteration 13, loss = 0.00057154
# Validation score: 0.993589
# Iteration 14, loss = 0.00052930
# Validation score: 0.994096
# Iteration 15, loss = 0.00050849
# Validation score: 0.994572
# Iteration 16, loss = 0.00047232
# Validation score: 0.994885
# Iteration 17, loss = 0.00045227
# Validation score: 0.995118
# Iteration 18, loss = 0.00043898
# Validation score: 0.995271
# Iteration 19, loss = 0.00042030
# Validation score: 0.995379
# Iteration 20, loss = 0.00040221
# Validation score: 0.995630
# Iteration 21, loss = 0.00039326
# Validation score: 0.995845
# Iteration 22, loss = 0.00039056
# Validation score: 0.996008
# Iteration 23, loss = 0.00038220
# Validation score: 0.996259
# Iteration 24, loss = 0.00036623
# Validation score: 0.996357
# Iteration 25, loss = 0.00034418
# Validation score: 0.996420
# Iteration 26, loss = 0.00034275
# Validation score: 0.996173
# Iteration 27, loss = 0.00035565
# Validation score: 0.996628
# Iteration 28, loss = 0.00031970
# Validation score: 0.997163
# Iteration 29, loss = 0.00031779
# Validation score: 0.997139
# Iteration 30, loss = 0.00029612
# Validation score: 0.997029
# Iteration 31, loss = 0.00030129
# Validation score: 0.997484
# Iteration 32, loss = 0.00027403
# Validation score: 0.997421
# Iteration 33, loss = 0.00028962
# Validation score: 0.997439
# Iteration 34, loss = 0.00027460
# Validation score: 0.997720
# Iteration 35, loss = 0.00027137
# Validation score: 0.997788
# Iteration 36, loss = 0.00027616
# Validation score: 0.997510
# Iteration 37, loss = 0.00026964
# Validation score: 0.997798
# Iteration 38, loss = 0.00029070
# Validation score: 0.997416
# Iteration 39, loss = 0.00030019
# Validation score: 0.997535
# Iteration 40, loss = 0.00024878
# Validation score: 0.997731
# Iteration 41, loss = 0.00025544
# Validation score: 0.997851
# Iteration 42, loss = 0.00025891
# Validation score: 0.997696
# Iteration 43, loss = 0.00026620
# Validation score: 0.998010
# Iteration 44, loss = 0.00024759
# Validation score: 0.997987
# Iteration 45, loss = 0.00024517
# Validation score: 0.997875
# Iteration 46, loss = 0.00025203
# Validation score: 0.998136
# Iteration 47, loss = 0.00024664
# Validation score: 0.997535
# Iteration 48, loss = 0.00024324
# Validation score: 0.998336
# Iteration 49, loss = 0.00023396
# Validation score: 0.998431
# Iteration 50, loss = 0.00025763
# Validation score: 0.998221
# Iteration 51, loss = 0.00029606
# Validation score: 0.998299
# Iteration 52, loss = 0.00023760
# Validation score: 0.998087
# Iteration 53, loss = 0.00022982
# Validation score: 0.997559
# Iteration 54, loss = 0.00024297
# Validation score: 0.998387
# Iteration 55, loss = 0.00022839
# Validation score: 0.998011
# Iteration 56, loss = 0.00023299
# Validation score: 0.998216
# Iteration 57, loss = 0.00025128
# Validation score: 0.998477
# Iteration 58, loss = 0.00022025
# Validation score: 0.998272
# Iteration 59, loss = 0.00021328
# Validation score: 0.998405
# Iteration 60, loss = 0.00022420
# Validation score: 0.998006
# Iteration 61, loss = 0.00024701
# Validation score: 0.998424
# Iteration 62, loss = 0.00022076
# Validation score: 0.998478
# Iteration 63, loss = 0.00023001
# Validation score: 0.997862
# Iteration 64, loss = 0.00022388
# Validation score: 0.997983
# Iteration 65, loss = 0.00023262
# Validation score: 0.998027
# Iteration 66, loss = 0.00022316
# Validation score: 0.997875
# Iteration 67, loss = 0.00022661
# Validation score: 0.998589
# Iteration 68, loss = 0.00020131
# Validation score: 0.998194
# Iteration 69, loss = 0.00022355
# Validation score: 0.997965
# Iteration 70, loss = 0.00024328
# Validation score: 0.997700
# Iteration 71, loss = 0.00021756
# Validation score: 0.998482
# Iteration 72, loss = 0.00020679
# Validation score: 0.998422
# Iteration 73, loss = 0.00022700
# Validation score: 0.998407
# Iteration 74, loss = 0.00021483
# Validation score: 0.998636
# Iteration 75, loss = 0.00020568
# Validation score: 0.998568
# Iteration 76, loss = 0.00020668
# Validation score: 0.998377
# Iteration 77, loss = 0.00021155
# Validation score: 0.998517
# Iteration 78, loss = 0.00020906
# Validation score: 0.998728
# Iteration 79, loss = 0.00021201
# Validation score: 0.998672
# Iteration 80, loss = 0.00023623
# Validation score: 0.998785
# Iteration 81, loss = 0.00021328
# Validation score: 0.998214
# Iteration 82, loss = 0.00021822
# Validation score: 0.997943
# Iteration 83, loss = 0.00020347
# Validation score: 0.998660
# Iteration 84, loss = 0.00021380
# Validation score: 0.997390
# Iteration 85, loss = 0.00019318
# Validation score: 0.998861
# Iteration 86, loss = 0.00020861
# Validation score: 0.998499
# Iteration 87, loss = 0.00020441
# Validation score: 0.998742
# Iteration 88, loss = 0.00019516
# Validation score: 0.998619
# Iteration 89, loss = 0.00018377
# Validation score: 0.998527
# Iteration 90, loss = 0.00021866
# Validation score: 0.998446
# Iteration 91, loss = 0.00019204
# Validation score: 0.998707
# Iteration 92, loss = 0.00019826
# Validation score: 0.998720
# Iteration 93, loss = 0.00019749
# Validation score: 0.998642
# Iteration 94, loss = 0.00022052
# Validation score: 0.998724
# Iteration 95, loss = 0.00020060
# Validation score: 0.997985
# Iteration 96, loss = 0.00018632
# Validation score: 0.998648
# Validation score did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.04699897
# Validation score: 0.946242
# Iteration 2, loss = 0.00337201
# Validation score: 0.973868
# Iteration 3, loss = 0.00175109
# Validation score: 0.982398
# Iteration 4, loss = 0.00136548
# Validation score: 0.984616
# Iteration 5, loss = 0.00120718
# Validation score: 0.986121
# Iteration 6, loss = 0.00111671
# Validation score: 0.986867
# Iteration 7, loss = 0.00104626
# Validation score: 0.987947
# Iteration 8, loss = 0.00095412
# Validation score: 0.989127
# Iteration 9, loss = 0.00085610
# Validation score: 0.990290
# Iteration 10, loss = 0.00074947
# Validation score: 0.991524
# Iteration 11, loss = 0.00065133
# Validation score: 0.992840
# Iteration 12, loss = 0.00058102
# Validation score: 0.993631
# Iteration 13, loss = 0.00053264
# Validation score: 0.994184
# Iteration 14, loss = 0.00049310
# Validation score: 0.994526
# Iteration 15, loss = 0.00047232
# Validation score: 0.994679
# Iteration 16, loss = 0.00044310
# Validation score: 0.995198
# Iteration 17, loss = 0.00041961
# Validation score: 0.995326
# Iteration 18, loss = 0.00041366
# Validation score: 0.995485
# Iteration 19, loss = 0.00039034
# Validation score: 0.995718
# Iteration 20, loss = 0.00038298
# Validation score: 0.995909
# Iteration 21, loss = 0.00037159
# Validation score: 0.995983
# Iteration 22, loss = 0.00038221
# Validation score: 0.996279
# Iteration 23, loss = 0.00035406
# Validation score: 0.996242
# Iteration 24, loss = 0.00035034
# Validation score: 0.996561
# Iteration 25, loss = 0.00032580
# Validation score: 0.996448
# Iteration 26, loss = 0.00032799
# Validation score: 0.996469
# Iteration 27, loss = 0.00032810
# Validation score: 0.996719
# Iteration 28, loss = 0.00030607
# Validation score: 0.997344
# Iteration 29, loss = 0.00030035
# Validation score: 0.997188
# Iteration 30, loss = 0.00028076
# Validation score: 0.997451
# Iteration 31, loss = 0.00028738
# Validation score: 0.997248
# Iteration 32, loss = 0.00026894
# Validation score: 0.997775
# Iteration 33, loss = 0.00029542
# Validation score: 0.997268
# Iteration 34, loss = 0.00026518
# Validation score: 0.997848
# Iteration 35, loss = 0.00025353
# Validation score: 0.997705
# Iteration 36, loss = 0.00026245
# Validation score: 0.997579
# Iteration 37, loss = 0.00025583
# Validation score: 0.997379
# Iteration 38, loss = 0.00025877
# Validation score: 0.997704
# Iteration 39, loss = 0.00027268
# Validation score: 0.997337
# Iteration 40, loss = 0.00024127
# Validation score: 0.997681
# Iteration 41, loss = 0.00025589
# Validation score: 0.997801
# Iteration 42, loss = 0.00025180
# Validation score: 0.998070
# Iteration 43, loss = 0.00023784
# Validation score: 0.997961
# Iteration 44, loss = 0.00025242
# Validation score: 0.998233
# Iteration 45, loss = 0.00023641
# Validation score: 0.998102
# Iteration 46, loss = 0.00024100
# Validation score: 0.998254
# Iteration 47, loss = 0.00024437
# Validation score: 0.998192
# Iteration 48, loss = 0.00023679
# Validation score: 0.998232
# Iteration 49, loss = 0.00024073
# Validation score: 0.998303
# Iteration 50, loss = 0.00023911
# Validation score: 0.998076
# Iteration 51, loss = 0.00025712
# Validation score: 0.998281
# Iteration 52, loss = 0.00024984
# Validation score: 0.998285
# Iteration 53, loss = 0.00022192
# Validation score: 0.997197
# Iteration 54, loss = 0.00024174
# Validation score: 0.997981
# Iteration 55, loss = 0.00024377
# Validation score: 0.998217
# Iteration 56, loss = 0.00022499
# Validation score: 0.998267
# Iteration 57, loss = 0.00022118
# Validation score: 0.998310
# Iteration 58, loss = 0.00021439
# Validation score: 0.998086
# Iteration 59, loss = 0.00021203
# Validation score: 0.998063
# Iteration 60, loss = 0.00021434
# Validation score: 0.998237
# Iteration 61, loss = 0.00024907
# Validation score: 0.998270
# Iteration 62, loss = 0.00020823
# Validation score: 0.998269
# Iteration 63, loss = 0.00022437
# Validation score: 0.997919
# Iteration 64, loss = 0.00021716
# Validation score: 0.998411
# Iteration 65, loss = 0.00022036
# Validation score: 0.998191
# Iteration 66, loss = 0.00021704
# Validation score: 0.998240
# Iteration 67, loss = 0.00022155
# Validation score: 0.998631
# Iteration 68, loss = 0.00020046
# Validation score: 0.998704
# Iteration 69, loss = 0.00021575
# Validation score: 0.998066
# Iteration 70, loss = 0.00022518
# Validation score: 0.998801
# Iteration 71, loss = 0.00020998
# Validation score: 0.997939
# Iteration 72, loss = 0.00022651
# Validation score: 0.998628
# Iteration 73, loss = 0.00020084
# Validation score: 0.998573
# Iteration 74, loss = 0.00020955
# Validation score: 0.998716
# Iteration 75, loss = 0.00021512
# Validation score: 0.998506
# Iteration 76, loss = 0.00022020
# Validation score: 0.998145
# Iteration 77, loss = 0.00022215
# Validation score: 0.998541
# Iteration 78, loss = 0.00020945
# Validation score: 0.998844
# Iteration 79, loss = 0.00023103
# Validation score: 0.998779
# Iteration 80, loss = 0.00021040
# Validation score: 0.998790
# Iteration 81, loss = 0.00019603
# Validation score: 0.998565
# Iteration 82, loss = 0.00021532
# Validation score: 0.998285
# Iteration 83, loss = 0.00020430
# Validation score: 0.998724
# Iteration 84, loss = 0.00020554
# Validation score: 0.998273
# Iteration 85, loss = 0.00019264
# Validation score: 0.998705
# Iteration 86, loss = 0.00020310
# Validation score: 0.998260
# Iteration 87, loss = 0.00021234
# Validation score: 0.998671
# Iteration 88, loss = 0.00019199
# Validation score: 0.998917
# Iteration 89, loss = 0.00017979
# Validation score: 0.998685
# Iteration 90, loss = 0.00023062
# Validation score: 0.998700
# Iteration 91, loss = 0.00019295
# Validation score: 0.998762
# Iteration 92, loss = 0.00019220
# Validation score: 0.998686
# Iteration 93, loss = 0.00020930
# Validation score: 0.998699
# Iteration 94, loss = 0.00019123
# Validation score: 0.998185
# Iteration 95, loss = 0.00019958
# Validation score: 0.998063
# Iteration 96, loss = 0.00018197
# Validation score: 0.998356
# Iteration 97, loss = 0.00017686
# Validation score: 0.998909
# Iteration 98, loss = 0.00019695
# Validation score: 0.998740
# Iteration 99, loss = 0.00019416
# Validation score: 0.998559
# Validation score did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.04674166
# Validation score: 0.947425
# Iteration 2, loss = 0.00336862
# Validation score: 0.974929
# Iteration 3, loss = 0.00172562
# Validation score: 0.982793
# Iteration 4, loss = 0.00134468
# Validation score: 0.985255
# Iteration 5, loss = 0.00119153
# Validation score: 0.986294
# Iteration 6, loss = 0.00110636
# Validation score: 0.987219
# Iteration 7, loss = 0.00103491
# Validation score: 0.987449
# Iteration 8, loss = 0.00093253
# Validation score: 0.989413
# Iteration 9, loss = 0.00082528
# Validation score: 0.990992
# Iteration 10, loss = 0.00072327
# Validation score: 0.992165
# Iteration 11, loss = 0.00062479
# Validation score: 0.993280
# Iteration 12, loss = 0.00055976
# Validation score: 0.994086
# Iteration 13, loss = 0.00051357
# Validation score: 0.994612
# Iteration 14, loss = 0.00048251
# Validation score: 0.994683
# Iteration 15, loss = 0.00046290
# Validation score: 0.994844
# Iteration 16, loss = 0.00043225
# Validation score: 0.995497
# Iteration 17, loss = 0.00041333
# Validation score: 0.995636
# Iteration 18, loss = 0.00039607
# Validation score: 0.995688
# Iteration 19, loss = 0.00038669
# Validation score: 0.996075
# Iteration 20, loss = 0.00037500
# Validation score: 0.996109
# Iteration 21, loss = 0.00035536
# Validation score: 0.996319
# Iteration 22, loss = 0.00038810
# Validation score: 0.996601
# Iteration 23, loss = 0.00033465
# Validation score: 0.996567
# Iteration 24, loss = 0.00033248
# Validation score: 0.996937
# Iteration 25, loss = 0.00031392
# Validation score: 0.997030
# Iteration 26, loss = 0.00030776
# Validation score: 0.997028
# Iteration 27, loss = 0.00031484
# Validation score: 0.997171
# Iteration 28, loss = 0.00029607
# Validation score: 0.997326
# Iteration 29, loss = 0.00027396
# Validation score: 0.997416
# Iteration 30, loss = 0.00028324
# Validation score: 0.997559
# Iteration 31, loss = 0.00027076
# Validation score: 0.997736
# Iteration 32, loss = 0.00025652
# Validation score: 0.997615
# Iteration 33, loss = 0.00027114
# Validation score: 0.997224
# Iteration 34, loss = 0.00026814
# Validation score: 0.998001
# Iteration 35, loss = 0.00027618
# Validation score: 0.996501
# Iteration 36, loss = 0.00026952
# Validation score: 0.997695
# Iteration 37, loss = 0.00026698
# Validation score: 0.997155
# Iteration 38, loss = 0.00024158
# Validation score: 0.997844
# Iteration 39, loss = 0.00027680
# Validation score: 0.997781
# Iteration 40, loss = 0.00023823
# Validation score: 0.998118
# Iteration 41, loss = 0.00023479
# Validation score: 0.997742
# Iteration 42, loss = 0.00023985
# Validation score: 0.997931
# Iteration 43, loss = 0.00024233
# Validation score: 0.997721
# Iteration 44, loss = 0.00025643
# Validation score: 0.998291
# Iteration 45, loss = 0.00022347
# Validation score: 0.998346
# Iteration 46, loss = 0.00022966
# Validation score: 0.998355
# Iteration 47, loss = 0.00022388
# Validation score: 0.998204
# Iteration 48, loss = 0.00021396
# Validation score: 0.998351
# Iteration 49, loss = 0.00024597
# Validation score: 0.997650
# Iteration 50, loss = 0.00022563
# Validation score: 0.998299
# Iteration 51, loss = 0.00023510
# Validation score: 0.998441
# Iteration 52, loss = 0.00024661
# Validation score: 0.998590
# Iteration 53, loss = 0.00022730
# Validation score: 0.995849
# Iteration 54, loss = 0.00021839
# Validation score: 0.998431
# Iteration 55, loss = 0.00023230
# Validation score: 0.997569
# Iteration 56, loss = 0.00021347
# Validation score: 0.998460
# Iteration 57, loss = 0.00023155
# Validation score: 0.998112
# Iteration 58, loss = 0.00020890
# Validation score: 0.997999
# Iteration 59, loss = 0.00020773
# Validation score: 0.998399
# Iteration 60, loss = 0.00021881
# Validation score: 0.998434
# Iteration 61, loss = 0.00023036
# Validation score: 0.998223
# Iteration 62, loss = 0.00021683
# Validation score: 0.998492
# Iteration 63, loss = 0.00019696
# Validation score: 0.998414
# Validation score did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# Cross validation score:
# [0.99864477 0.99828034 0.99895259 0.99881097 0.9982477 ]
# 0.9992182899479649
# 0.9988340034325398
