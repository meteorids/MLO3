# %%
# This code is to process .he5 format datafiles from NASA - OMI
# 2022 ___MILOS___ 2022
# milostipanov@gmail.com

# %%
# Loading the neccessary libraries

import os
import h5py
import pandas as pd
import datetime

# %%
# NOTE: seems like a h5py file can be opened only by 1 program/library whatever at the time. Hence the 2 for loops

# Loading all file names within a directory to datafiles list.
datafiles=[]
year=[]
month=[]
day=[]
doy=[]

# Give the path to the folder where all the he5 datafiles located. Don't forget the / at the end of the path (for he second for loop).

datapath = '../Data/OMI/2014_dummy/'

for filename in os.listdir(datapath):
    datafiles.append(filename)
#    year.append(filename[21:25])
#    month.append(filename[26:28])
#    day.append(filename[28:30])
    year.append(filename[20:24])
    month.append(filename[25:27])
    day.append(filename[27:29])
#    print(filename[20:24],filename[25:27],filename[27:29],'\n')
#    print(filename[21:25],filename[26:28],filename[28:30],'\n')
#    doy.append(datetime.datetime.strptime(filename[20:24]+filename[25:27]+filename[27:29], '%Y%m%d').timetuple().tm_yday)
    
    
# Iterating through the list of filenames and getting rid of missing data (negative values) and calculationg means    
averages=[]
    
for name in datafiles:
    f = h5py.File(datapath+str(name))
    data = f['HDFEOS/GRIDS/ColumnAmountO3/Data Fields/ColumnAmountO3']
#    data = f['HDFEOS/GRIDS/OMI Column Amount O3/Data Fields/ColumnAmountO3']
#    data = f['HDFEOS/ADDITIONAL/GRIDS/Omi_column_Amount_O3']
    df = pd.DataFrame(data)
    print(df)
    positive_values = df[df>0]
    mean_rows = positive_values.mean(numeric_only=True)
    mean = mean_rows.mean()
    averages.append(mean)
  



# df = pd.DataFrame({
#    'YEAR': year,
#    'MONTH': month,
#    'DAY': day,
#    'DOY': doy,
#    'OMI_Ave': averages
#})


df.to_csv("./OMI-dataprocess-output/omi_daily_means_2014_10.csv")
# Out:
#              0             1             2             3             4     \
# 0    2.678000e+02  2.678000e+02  2.678000e+02  2.678000e+02  2.678000e+02
# 1    2.769000e+02  2.769000e+02  2.769000e+02  2.769000e+02  2.769000e+02
# 2    2.762000e+02  2.762000e+02  2.762000e+02  2.762000e+02  2.762000e+02
# 3    2.735000e+02  2.735000e+02  2.735000e+02  2.735000e+02  2.735000e+02
# 4    2.755000e+02  2.755000e+02  2.755000e+02  2.755000e+02  2.755000e+02
# ..            ...           ...           ...           ...           ...
# 715 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30
# 716 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30
# 717 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30
# 718 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30
# 719 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30 -1.267651e+30
#
#              5             6             7             8             9     \
# ...
